# %%
import pandas as pd

# %%
iris_df = pd.read_csv('iris.csv')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
new_iris_df=iris_df.drop(['class'],axis=1)

# %%
new_iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
output_file_path = "new_iris_data.csv"
new_iris_df.to_csv(output_file_path, index=False)

# %%
sd = pd.read_csv('Shopping_data.csv')
sd
# Out:
#      CustomerID Card Member   Age  Annual Income  Spending Score (1-100)
# 0             1         Yes  19.0          15000                    39.0
# 1             2         Yes  21.0          15000                    81.0
# 2             3          No  20.0          16000                     6.0
# 3             4          No  23.0          16000                    77.0
# 4             5          No  31.0          17000                    40.0
# ..          ...         ...   ...            ...                     ...
# 198         199          No  35.0         120000                    79.0
# 199         200          No  45.0         126000                    28.0
# 200         201         Yes  32.0         126000                    74.0
# 201         202         Yes  32.0         137000                    18.0
# 202         203         Yes  30.0         137000                    83.0
#
# [203 rows x 5 columns]

# %%
sd.columns
# Out:
# Index(['CustomerID', 'Card Member', 'Age', 'Annual Income',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df_shopping = sd.dropna()

# %%
df_shopping2=sd.dropna()
df_shopping2
# Out:
#      CustomerID Card Member   Age  Annual Income  Spending Score (1-100)
# 0             1         Yes  19.0          15000                    39.0
# 1             2         Yes  21.0          15000                    81.0
# 2             3          No  20.0          16000                     6.0
# 3             4          No  23.0          16000                    77.0
# 4             5          No  31.0          17000                    40.0
# ..          ...         ...   ...            ...                     ...
# 198         199          No  35.0         120000                    79.0
# 199         200          No  45.0         126000                    28.0
# 200         201         Yes  32.0         126000                    74.0
# 201         202         Yes  32.0         137000                    18.0
# 202         203         Yes  30.0         137000                    83.0
#
# [200 rows x 5 columns]

# %%
df_shopping
# Out:
#      CustomerID Card Member   Age  Annual Income  Spending Score (1-100)
# 0             1         Yes  19.0          15000                    39.0
# 1             2         Yes  21.0          15000                    81.0
# 2             3          No  20.0          16000                     6.0
# 3             4          No  23.0          16000                    77.0
# 4             5          No  31.0          17000                    40.0
# ..          ...         ...   ...            ...                     ...
# 198         199          No  35.0         120000                    79.0
# 199         200          No  45.0         126000                    28.0
# 200         201         Yes  32.0         126000                    74.0
# 201         202         Yes  32.0         137000                    18.0
# 202         203         Yes  30.0         137000                    83.0
#
# [200 rows x 5 columns]

# %%
df_shopping.drop(columns=["CustomerID"],inplace=True)
# Out:
# C:\Users\slash\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_shopping2.drop(columns=["CustomerID"],inplace=True)
# Out:
# C:\Users\slash\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_shopping2
# Out:
#     Card Member   Age  Annual Income  Spending Score (1-100)
# 0           Yes  19.0          15000                    39.0
# 1           Yes  21.0          15000                    81.0
# 2            No  20.0          16000                     6.0
# 3            No  23.0          16000                    77.0
# 4            No  31.0          17000                    40.0
# ..          ...   ...            ...                     ...
# 198          No  35.0         120000                    79.0
# 199          No  45.0         126000                    28.0
# 200         Yes  32.0         126000                    74.0
# 201         Yes  32.0         137000                    18.0
# 202         Yes  30.0         137000                    83.0
#
# [200 rows x 4 columns]

# %%
def change_string(member):
    if member == "Yes":
        return 1
    else:
        return 0
df_shopping2["Card Member"]=df_shopping2["Card Member"].apply(change_string)
df_shopping2
# Out:
# <ipython-input-26-8e8a62df7124>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shopping2["Card Member"]=df_shopping2["Card Member"].apply(change_string)
#      Card Member   Age  Annual Income  Spending Score (1-100)
# 0              1  19.0          15000                    39.0
# 1              1  21.0          15000                    81.0
# 2              0  20.0          16000                     6.0
# 3              0  23.0          16000                    77.0
# 4              0  31.0          17000                    40.0
# ..           ...   ...            ...                     ...
# 198            0  35.0         120000                    79.0
# 199            0  45.0         126000                    28.0
# ...

# %%
df_shopping2.head(20)
# Out:
#     Card Member   Age  Annual Income  Spending Score (1-100)
# 0             1  19.0          15000                    39.0
# 1             1  21.0          15000                    81.0
# 2             0  20.0          16000                     6.0
# 3             0  23.0          16000                    77.0
# 4             0  31.0          17000                    40.0
# 5             0  22.0          17000                    76.0
# 6             0  35.0          18000                     6.0
# 7             0  23.0          18000                    94.0
# 8             1  64.0          19000                     3.0
# 9             0  30.0          19000                    72.0
# 10            1  67.0          19000                    14.0
# 11            0  35.0          19000                    99.0
# 12            0  58.0          20000                    15.0
# 13            0  24.0          20000                    77.0
# ...

# %%
df_shopping2["Annual Income"]=df_shopping2["Annual Income"] / 1000
df_shopping2.head()
# Out:
# <ipython-input-29-3b33d0605e53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shopping2["Annual Income"]=df_shopping2["Annual Income"] / 1000
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0           15.0                    39.0
# 1            1  21.0           15.0                    81.0
# 2            0  20.0           16.0                     6.0
# 3            0  23.0           16.0                    77.0
# 4            0  31.0           17.0                    40.0

# %%
# Saving cleaned data
file_path = "shopping_data_cleaned.csv"
df_shopping2.to_csv(file_path, index=False)
